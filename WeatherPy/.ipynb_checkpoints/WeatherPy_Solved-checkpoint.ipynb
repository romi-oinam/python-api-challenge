# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %%
# Set the API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=metric&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{base_url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = (city_weather["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | puno
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | puerto natales
# Processing Record 6 of Set 1 | bilibino
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | port isabel
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | katra
# Processing Record 11 of Set 1 | antsohihy
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | nogales
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | mirny
# Processing Record 16 of Set 1 | kailua-kona
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | mawu
# Processing Record 19 of Set 1 | anadyr
# Processing Record 20 of Set 1 | keflavik
# Processing Record 21 of Set 1 | marabba
# Processing Record 22 of Set 1 | scarborough
# Processing Record 23 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 1 | zeya
# Processing Record 25 of Set 1 | as sulayyil
# Processing Record 26 of Set 1 | blackmans bay
# Processing Record 27 of Set 1 | waynesboro
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | lamas
# Processing Record 31 of Set 1 | bamyan
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | carboneras
# Processing Record 34 of Set 1 | tazovsky
# Processing Record 35 of Set 1 | yelm
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | nova vicosa
# Processing Record 38 of Set 1 | farasan
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | papao
# Processing Record 41 of Set 1 | hammerfest
# Processing Record 42 of Set 1 | porto velho
# Processing Record 43 of Set 1 | raja
# Processing Record 44 of Set 1 | liuhe
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | wailua homesteads
# Processing Record 47 of Set 1 | silver springs
# Processing Record 48 of Set 1 | minas de marcona
# Processing Record 49 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 50 of Set 1 | picui
# Processing Record 0 of Set 2 | port mathurin
# Processing Record 1 of Set 2 | margaret river
# Processing Record 2 of Set 2 | hateg
# Processing Record 3 of Set 2 | dolisie
# Processing Record 4 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 2 | saipan
# Processing Record 6 of Set 2 | nacala
# Processing Record 7 of Set 2 | batamshinskiy
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | bikenibeu village
# Processing Record 10 of Set 2 | grytviken
# Processing Record 11 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 12 of Set 2 | machico
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | st. john's
# Processing Record 15 of Set 2 | oranjemund
# Processing Record 16 of Set 2 | ambodifotatra
# Processing Record 17 of Set 2 | placido de castro
# Processing Record 36 of Set 3 | seaford
# Processing Record 37 of Set 3 | guelma
# Processing Record 38 of Set 3 | giporlos
# Processing Record 39 of Set 3 | portland
# Processing Record 40 of Set 3 | tidjikja
# Processing Record 41 of Set 3 | kayyerkan
# Processing Record 42 of Set 3 | berezovyy
# Processing Record 43 of Set 3 | jiuquan
# Processing Record 44 of Set 3 | richards bay
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | uturoa
# Processing Record 47 of Set 3 | tadine
# Processing Record 48 of Set 3 | mazatlan
# Processing Record 49 of Set 3 | tamandare
# Processing Record 0 of Set 4 | lihue
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | tocopilla
# Processing Record 3 of Set 4 | libertad
# Processing Record 4 of Set 4 | pushkinskiye gory
# Processing Record 5 of Set 4 | gebeit
# Processing Record 6 of Set 4 | tura
# Processing Record 7 of Set 4 | minbu
# Processing Record 8 of Set 4 | poblacion, san felipe
# Processing Record 9 of Set 4 | papatowai
# Processing Record 10 of Set 4 | kangding
# Processing Record 11 of Set 4 | saint-francois
# Processing Record 12 of Set 4 | haimen
# Processing Record 13 of Set 4 | crane
# Processing Record 14 of Set 4 | fort bragg
# Processing Record 15 of Set 4 | kisangani
# Processing Record 16 of Set 4 | aktau
# Processing Record 17 of Set 4 | walvis bay
# Processing Record 18 of Set 4 | yuci
# Processing Record 19 of Set 4 | klyuchi
# Processing Record 20 of Set 4 | yelizovo
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | nevel'sk
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | hermanus
# Processing Record 25 of Set 4 | afaahiti
# Processing Record 26 of Set 4 | namibe
# Processing Record 27 of Set 4 | makarov
# Processing Record 28 of Set 4 | galvan
# Processing Record 29 of Set 4 | kagizman
# Processing Record 30 of Set 4 | tevriz
# Processing Record 31 of Set 4 | kiamba
# Processing Record 32 of Set 4 | newman
# Processing Record 33 of Set 4 | nemuro
# Processing Record 34 of Set 4 | ta`u
# Processing Record 35 of Set 4 | hassi messaoud
# Processing Record 36 of Set 4 | zhangjiakou
# Processing Record 37 of Set 4 | palikir - national government center
# Processing Record 38 of Set 4 | tsiombe
# Processing Record 39 of Set 4 | badger
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | prineville
# Processing Record 42 of Set 4 | woolgoolga
# Processing Record 43 of Set 4 | broome
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | zaozersk
# Processing Record 46 of Set 4 | holualoa
# Processing Record 47 of Set 4 | half moon bay
# Processing Record 48 of Set 4 | lodwar
# Processing Record 49 of Set 4 | plouzane
# Processing Record 0 of Set 5 | santa ana de yacuma
# Processing Record 1 of Set 5 | strezhevoy
# Processing Record 2 of Set 5 | mitu
# Processing Record 3 of Set 5 | kodinsk
# Processing Record 4 of Set 5 | vikulovo
# Processing Record 5 of Set 5 | nizhnyaya poyma
# Processing Record 6 of Set 5 | santa cruz del sur
# Processing Record 7 of Set 5 | wewak
# Processing Record 8 of Set 5 | benjamin aceval
# Processing Record 9 of Set 5 | kapa'a
# Processing Record 10 of Set 5 | esmeraldas
# Processing Record 11 of Set 5 | san luis de la loma
# Processing Record 12 of Set 5 | celestun
# Processing Record 13 of Set 5 | whitehorse
# Processing Record 14 of Set 5 | invercargill
# Processing Record 15 of Set 5 | melekeok village
# Processing Record 16 of Set 5 | lompoc
# Processing Record 17 of Set 5 | smithers
# Processing Record 18 of Set 5 | tarabha
# Processing Record 19 of Set 5 | bosaso
# Processing Record 20 of Set 5 | kyosai
# Processing Record 21 of Set 5 | ngara
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | dudinka
# Processing Record 24 of Set 5 | rockport
# Processing Record 25 of Set 5 | duncan town
# City not found. Skipping...
# Processing Record 26 of Set 5 | paran'ga
# Processing Record 27 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 5 | shadegan
# Processing Record 29 of Set 5 | chibougamau
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | weno
# Processing Record 32 of Set 5 | shingu
# Processing Record 33 of Set 5 | constantia
# Processing Record 34 of Set 5 | phan rang-thap cham
# Processing Record 35 of Set 5 | colonia
# Processing Record 36 of Set 5 | coron
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | sinop
# Processing Record 39 of Set 5 | senanga
# Processing Record 40 of Set 5 | rudsar
# Processing Record 41 of Set 5 | san antonio de pale
# Processing Record 42 of Set 5 | akureyri
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | punta arenas
# Processing Record 45 of Set 5 | orapa
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | sierra grande
# Processing Record 48 of Set 5 | nar'yan-mar
# Processing Record 49 of Set 5 | kem'
# Processing Record 0 of Set 6 | baruun-urt
# Processing Record 1 of Set 6 | heihe
# Processing Record 2 of Set 6 | akrehamn
# Processing Record 3 of Set 6 | hawaiian paradise park
# Processing Record 4 of Set 6 | at taj
# Processing Record 5 of Set 6 | ribeira brava
# Processing Record 6 of Set 6 | ermoupolis
# Processing Record 7 of Set 6 | isafjordur
# Processing Record 8 of Set 6 | kingston
# Processing Record 9 of Set 6 | isola delle femmine
# Processing Record 10 of Set 6 | ola
# Processing Record 11 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 6 | novo aripuana
# Processing Record 13 of Set 6 | nikolayevsk-on-amure
# Processing Record 14 of Set 6 | yuzhne
# Processing Record 15 of Set 6 | tolanaro
# Processing Record 16 of Set 6 | ghat
# Processing Record 17 of Set 6 | filadelfia
# Processing Record 18 of Set 6 | yaren
# Processing Record 19 of Set 6 | kerikeri
# Processing Record 20 of Set 6 | pointe aux piments
# Processing Record 21 of Set 6 | kidal
# Processing Record 22 of Set 6 | dhidhdhoo
# Processing Record 23 of Set 6 | vilyuchinsk
# Processing Record 24 of Set 6 | shakawe
# Processing Record 25 of Set 6 | nyurba
# Processing Record 26 of Set 6 | liwa
# Processing Record 27 of Set 6 | muisne
# Processing Record 28 of Set 6 | trincomalee
# Processing Record 29 of Set 6 | graneros
# Processing Record 30 of Set 6 | nova sintra
# Processing Record 31 of Set 6 | natal
# Processing Record 32 of Set 6 | rabaul
# Processing Record 33 of Set 6 | mayuge
# Processing Record 34 of Set 6 | taoudenni
# Processing Record 35 of Set 6 | san miguel
# Processing Record 36 of Set 6 | ust'-kalmanka
# Processing Record 37 of Set 6 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 38 of Set 6 | lat yao
# Processing Record 39 of Set 6 | karosta
# City not found. Skipping...
# Processing Record 40 of Set 6 | vernon
# Processing Record 41 of Set 6 | new norfolk
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | kuala belait
# Processing Record 44 of Set 6 | chulakkurgan
# Processing Record 45 of Set 6 | nantucket
# Processing Record 46 of Set 6 | ulaangom
# Processing Record 47 of Set 6 | hadibu
# Processing Record 48 of Set 6 | ciudad lazaro cardenas
# Processing Record 49 of Set 6 | tshikapa
# Processing Record 0 of Set 7 | lemvig
# Processing Record 1 of Set 7 | ha'il
# Processing Record 2 of Set 7 | ubinskoye
# Processing Record 3 of Set 7 | bodo
# Processing Record 4 of Set 7 | kone
# Processing Record 5 of Set 7 | springfield
# Processing Record 6 of Set 7 | enewetak
# Processing Record 7 of Set 7 | pangoa
# Processing Record 8 of Set 7 | selfoss
# Processing Record 9 of Set 7 | zhanjiang
# Processing Record 10 of Set 7 | luderitz
# Processing Record 11 of Set 7 | brookings
# Processing Record 12 of Set 7 | rajapur
# Processing Record 13 of Set 7 | sidney
# Processing Record 14 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 7 | jha-jha
# Processing Record 16 of Set 7 | nieuw amsterdam
# Processing Record 17 of Set 7 | itoman
# Processing Record 18 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 19 of Set 7 | kaduna
# Processing Record 20 of Set 7 | maumere
# Processing Record 21 of Set 7 | vadso
# Processing Record 22 of Set 7 | sao felix do xingu
# Processing Record 23 of Set 7 | la goulette
# Processing Record 24 of Set 7 | cestos city
# Processing Record 25 of Set 7 | happy valley-goose bay
# Processing Record 26 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 27 of Set 7 | thunder bay
# Processing Record 28 of Set 7 | morant bay
# Processing Record 29 of Set 7 | carnarvon
# Processing Record 30 of Set 7 | samborondon
# Processing Record 31 of Set 7 | brisas de zicatela
# Processing Record 32 of Set 7 | fortuna
# Processing Record 33 of Set 7 | scottburgh
# Processing Record 34 of Set 7 | ghanzi
# Processing Record 35 of Set 7 | deniliquin
# Processing Record 36 of Set 7 | saurimo
# Processing Record 37 of Set 7 | val-d'or
# Processing Record 38 of Set 7 | sisimiut
# Processing Record 8 of Set 9 | taipei
# Processing Record 9 of Set 9 | kristiansund
# Processing Record 10 of Set 9 | bamboo flat
# Processing Record 11 of Set 9 | barcelos
# Processing Record 12 of Set 9 | xining
# Processing Record 13 of Set 9 | nerja
# Processing Record 14 of Set 9 | la passe
# Processing Record 15 of Set 9 | enterprise
# Processing Record 16 of Set 9 | awjilah
# Processing Record 17 of Set 9 | iskateley
# Processing Record 18 of Set 9 | la'ie
# Processing Record 19 of Set 9 | quimili
# Processing Record 20 of Set 9 | moussoro
# Processing Record 21 of Set 9 | zabaykal'sk
# Processing Record 22 of Set 9 | geraldton
# Processing Record 23 of Set 9 | vilyuysk
# Processing Record 24 of Set 9 | springbok
# Processing Record 25 of Set 9 | kimberley
# Processing Record 26 of Set 9 | mogok
# Processing Record 27 of Set 9 | kaedi
# Processing Record 28 of Set 9 | al hazm
# Processing Record 29 of Set 9 | necochea
# Processing Record 30 of Set 9 | dakhla
# Processing Record 31 of Set 9 | port douglas
# Processing Record 32 of Set 9 | al burayqah
# Processing Record 33 of Set 9 | antonio enes
# Processing Record 34 of Set 9 | san patricio
# Processing Record 35 of Set 9 | college
# Processing Record 36 of Set 9 | cromwell
# Processing Record 37 of Set 9 | fale old settlement
# Processing Record 38 of Set 9 | kousa
# Processing Record 39 of Set 9 | juan griego
# Processing Record 40 of Set 9 | tadmur
# Processing Record 41 of Set 9 | praia
# Processing Record 42 of Set 9 | wenchang
# Processing Record 43 of Set 9 | vavoua
# Processing Record 44 of Set 9 | galle
# Processing Record 45 of Set 9 | barra de santo antonio
# Processing Record 46 of Set 9 | punto fijo
# Processing Record 47 of Set 9 | bonthe
# Processing Record 48 of Set 9 | rio grande
# Processing Record 49 of Set 9 | grants
# Processing Record 0 of Set 10 | mao
# Processing Record 1 of Set 10 | pskov
# Processing Record 2 of Set 10 | genhe
# Processing Record 3 of Set 10 | dhanera
# Processing Record 4 of Set 10 | praia da vitoria
# Processing Record 5 of Set 10 | tuburan
# Processing Record 6 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 7 of Set 10 | ylitornio
# Processing Record 8 of Set 10 | chegdomyn
# Processing Record 9 of Set 10 | ebaye
# Processing Record 10 of Set 10 | tamanrasset
# Processing Record 11 of Set 10 | zarinsk
# Processing Record 12 of Set 10 | gobabis
# Processing Record 13 of Set 10 | mili
# Processing Record 14 of Set 10 | cruz alta
# Processing Record 15 of Set 10 | howard springs
# Processing Record 16 of Set 10 | corner brook
# Processing Record 17 of Set 10 | port augusta
# Processing Record 18 of Set 10 | katsuura
# Processing Record 19 of Set 10 | gutao
# Processing Record 20 of Set 10 | trevelin
# Processing Record 21 of Set 10 | pitimbu
# Processing Record 22 of Set 10 | moberly
# Processing Record 23 of Set 10 | puerto baquerizo moreno
# Processing Record 24 of Set 10 | kalmunai
# Processing Record 25 of Set 10 | cold springs
# Processing Record 26 of Set 10 | arno
# Processing Record 27 of Set 10 | freetown
# Processing Record 28 of Set 10 | djibo
# Processing Record 29 of Set 10 | mananara
# Processing Record 30 of Set 10 | plumas lake
# Processing Record 31 of Set 10 | mandera
# Processing Record 32 of Set 10 | al hasaheisa
# Processing Record 33 of Set 10 | seybaplaya
# Processing Record 34 of Set 10 | kyrenia
# Processing Record 35 of Set 10 | anar darah
# Processing Record 36 of Set 10 | wuda
# Processing Record 37 of Set 10 | umba
# Processing Record 38 of Set 10 | borovskoy
# Processing Record 39 of Set 10 | kattivakkam
# Processing Record 40 of Set 10 | abeche
# Processing Record 41 of Set 10 | moratuwa
# Processing Record 42 of Set 10 | saudarkrokur
# Processing Record 43 of Set 10 | bafata
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | punta cana
# Processing Record 46 of Set 10 | manacapuru
# Processing Record 47 of Set 10 | arkhangel'sk
# Processing Record 48 of Set 10 | jalai nur
# Processing Record 49 of Set 10 | paracuru
# Processing Record 0 of Set 11 | nyagan
# Processing Record 1 of Set 11 | shizunai-furukawacho
# Processing Record 2 of Set 11 | la cruz
# Processing Record 3 of Set 11 | ocos
# Processing Record 4 of Set 11 | aomori
# Processing Record 5 of Set 11 | mondragon
# Processing Record 6 of Set 11 | benguela
# Processing Record 7 of Set 11 | kanniyakumari
# Processing Record 8 of Set 11 | kirensk
# Processing Record 9 of Set 11 | hancheng
# Processing Record 10 of Set 11 | qarazhal
# Processing Record 11 of Set 11 | banda aceh
# Processing Record 12 of Set 11 | wladyslawowo
# Processing Record 13 of Set 11 | pangai
# Processing Record 14 of Set 11 | tofol
# Processing Record 15 of Set 11 | maple grove
# Processing Record 16 of Set 11 | wynyard
# Processing Record 17 of Set 11 | kolondieba
# Processing Record 18 of Set 11 | belley
# Processing Record 19 of Set 11 | severo-yeniseyskiy
# Processing Record 20 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 21 of Set 11 | sangmelima
# Processing Record 22 of Set 11 | miles city
# Processing Record 23 of Set 11 | simplicio mendes
# Processing Record 24 of Set 11 | mtambile
# Processing Record 25 of Set 11 | island harbour
# Processing Record 26 of Set 11 | salalah
# Processing Record 27 of Set 11 | maisi
# Processing Record 28 of Set 11 | lincoln city
# Processing Record 29 of Set 11 | mberubu
# City not found. Skipping...
# Processing Record 30 of Set 11 | polatli
# Processing Record 31 of Set 11 | olinda
# Processing Record 32 of Set 11 | morehead city
# Processing Record 33 of Set 11 | callao
# Processing Record 34 of Set 11 | sinabang
# Processing Record 35 of Set 11 | sampit
# Processing Record 36 of Set 11 | el hamma
# Processing Record 37 of Set 11 | bethlehem
# Processing Record 38 of Set 11 | nola
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | new plymouth
# Processing Record 41 of Set 11 | mangrol
# Processing Record 42 of Set 11 | zefta
# Processing Record 43 of Set 11 | atherton
# Processing Record 44 of Set 11 | gornozavodsk
# Processing Record 45 of Set 11 | mazagao
# Processing Record 46 of Set 11 | huaicheng
# Processing Record 47 of Set 11 | hoxtolgay
# City not found. Skipping...
# Processing Record 48 of Set 11 | paramirim
# Processing Record 49 of Set 11 | saynshand
# Processing Record 0 of Set 12 | kotlas
# Processing Record 1 of Set 12 | johnstown
# Processing Record 2 of Set 12 | isla vista
# Processing Record 3 of Set 12 | cabedelo
# Processing Record 4 of Set 12 | karungdong
# Processing Record 5 of Set 12 | hanceville
# Processing Record 6 of Set 12 | ilirska bistrica
# Processing Record 7 of Set 12 | romitan shahri
# City not found. Skipping...
# Processing Record 8 of Set 12 | sao jose da coroa grande
# Processing Record 9 of Set 12 | loushanguan
# Processing Record 10 of Set 12 | enriquillo
# Processing Record 11 of Set 12 | ouadda
# Processing Record 12 of Set 12 | columbus
# Processing Record 13 of Set 12 | snyder
# Processing Record 14 of Set 12 | puerto leguizamo
# Processing Record 15 of Set 12 | sao geraldo do araguaia
# Processing Record 16 of Set 12 | collie
# Processing Record 17 of Set 12 | novoazovs'k
# Processing Record 18 of Set 12 | hithadhoo
# Processing Record 19 of Set 12 | piney green
# Processing Record 20 of Set 12 | nouadhibou
# Processing Record 21 of Set 12 | chui
# Processing Record 22 of Set 12 | omuthiya
# City not found. Skipping...
# Processing Record 23 of Set 12 | gadzhiyevo
# Processing Record 24 of Set 12 | alice springs
# Processing Record 25 of Set 12 | cadale
# Processing Record 26 of Set 12 | dolores
# Processing Record 27 of Set 12 | deogarh
# Processing Record 28 of Set 12 | susuman
# Processing Record 29 of Set 12 | voi
# Processing Record 30 of Set 12 | paradera
# City not found. Skipping...
# Processing Record 31 of Set 12 | ust'-barguzin
# Processing Record 32 of Set 12 | mbaiki
# Processing Record 33 of Set 12 | byron bay
# Processing Record 34 of Set 12 | skutskar
# City not found. Skipping...
# Processing Record 35 of Set 12 | quellon
# Processing Record 36 of Set 12 | lysekil
# Processing Record 37 of Set 12 | isiro
# Processing Record 38 of Set 12 | utete
# Processing Record 39 of Set 12 | chadan
# Processing Record 40 of Set 12 | juye
# Processing Record 41 of Set 12 | west mackay
# Processing Record 42 of Set 12 | kralendijk
# Processing Record 43 of Set 12 | belmonte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df=city_data_df[["City", "Lat","Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]]

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      bredasdorp -34.5322   20.0403     17.01        65         100
# 1           tiksi  71.6872  128.8694    -23.03       100         100
# 2            puno -15.8333  -70.0333     13.95        33          41
# 3        waitangi -43.9535 -176.5597     16.57        92         100
# 4  puerto natales -51.7236  -72.4875     13.25        50          75
#
#    Wind Speed Country        Date
# 0        1.18      ZA  1681934069
# 1        1.45      RU  1681933995
# 2        4.59      PE  1681934072
# 3        4.02      NZ  1681934073
# 4       14.40      CL  1681934073

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %% [markdown]
# # Create the Scatter Plots Requested
# Latitude Vs. Temperature¶

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.75, edgecolors="k")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Max Temperature (2023/04/18)')
plt.xlabel("Latitude ")
plt.ylabel("Temperature (C)")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.75, edgecolors="k")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Humidity (2023/04/18)')
plt.xlabel("Latitude ")
plt.ylabel("Himidity (%)")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.75, edgecolors="k")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Couldiness (2023/04/18)')
plt.xlabel("Latitude ")
plt.ylabel("Couldiness (%)")
plt.grid(True) 
plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.75, edgecolors="k")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title('City Latitude vs. Wind Speed (2023/04/18)')
plt.xlabel("Latitude ")
plt.ylabel("Couldiness (%)")
plt.grid(True) 
plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# # Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1        tiksi  71.6872  128.8694    -23.03       100         100        1.45
# 5     bilibino  68.0546  166.4372     -4.72        87         100        1.10
# 6      iqaluit  63.7506  -68.5145     -9.15        92         100        0.00
# 7  port isabel  26.0734  -97.2086     29.05        73         100        8.75
# 9        katra  32.9833   74.9500     13.98        79          18        4.12
#
#   Country        Date
# 1      RU  1681933995
# 5      RU  1681934074
# 6      CA  1681934075
# 7      US  1681934075
# 9      IN  1681934076

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      bredasdorp -34.5322   20.0403     17.01        65         100
# 2            puno -15.8333  -70.0333     13.95        33          41
# 3        waitangi -43.9535 -176.5597     16.57        92         100
# 4  puerto natales -51.7236  -72.4875     13.25        50          75
# 8       adamstown -25.0660 -130.1015     24.90        75          70
#
#    Wind Speed Country        Date
# 0        1.18      ZA  1681934069
# 2        4.59      PE  1681934072
# 3        4.02      NZ  1681934073
# 4       14.40      CL  1681934073
# 8        3.55      PN  1681934076

# %% [markdown]
# # Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = -0.57x + 35.56
# The r-squared is: -0.8629749368600242

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.35x + 29.5
# The r-squared is: 0.7594803782706808

# %% [markdown]
# # Discussion about the linear relationship:
# In the nothern hemisphere, the regression displays a negative correlation. Hence, as you move away from the equator the temperature decreases.
# In the southern hemisphere, the regression displays a positive correlation. Hence, as you get closer to the equator the temperature increases.

# %% [markdown]
# # Humidity vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.25x + 58.16
# The r-squared is: 0.19753043688364327

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.23x + 77.88
# The r-squared is: 0.16385510009005735

# %% [markdown]
# # Discussion about the linear relationship:
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# # Cloudiness vs. Latitude Linear Regression Plot¶

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.4x + 40.17
# The r-squared is: 0.19041377982432114

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.17x + 60.36
# The r-squared is: 0.058182428588787784

# %% [markdown]
# # Discussion about the linear relationship:
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# # Wind Speed vs. Latitude Linear Regression Plot¶

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.0x + 4.03
# The r-squared is: 0.0022390526826928134

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = -0.06x + 2.67
# The r-squared is: -0.3024379618842757

# %% [markdown]
# # Discussion about the linear relationship:
# The regression does not display much of a correlation between the data sets.
